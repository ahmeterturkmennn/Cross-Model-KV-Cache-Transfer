# %%
# !pip uninstall -y transformers huggingface-hub tokenizers
# !pip install -q \
    "transformers==4.56.2" \
    "huggingface-hub==0.35.3" \
    "tokenizers==0.22.0" \
    "accelerate==1.6.0"
# Out:
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0
# Found existing installation: huggingface_hub 1.11.0
# Uninstalling huggingface_hub-1.11.0:
#   Successfully uninstalled huggingface_hub-1.11.0
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 94.5 MB/s eta 0:00:00:00:01:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 87.6 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 26.1 MB/s eta 0:00:00

# %%
from datasets import load_dataset

ds = load_dataset(
    "HuggingFaceFW/fineweb-edu",
    "default",
    split="train",
    streaming=True,
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Resolving data files:   0%|          | 0/2410 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/2410 [00:00<?, ?it/s]

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
small_model_name = "Qwen/Qwen3-1.7B"
small_tokenizer = AutoTokenizer.from_pretrained(small_model_name)
large_model_name = "Qwen/Qwen3-4B"
large_tokenizer = AutoTokenizer.from_pretrained(large_model_name)
small_model = AutoModelForCausalLM.from_pretrained(small_model_name,torch_dtype="auto",device_map="auto")
large_model = AutoModelForCausalLM.from_pretrained(large_model_name,torch_dtype="auto",device_map="auto")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/622M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
sequences = []

for example in ds:
    ids = small_tokenizer(
        example["text"],
        add_special_tokens=False,
    )["input_ids"]

    if len(ids) >= 1024:
        sequences.append(ids[:1024])

    if len(sequences) == 500:
        break

# %%
print(small_model.config)
# Out:
# Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151645,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 40960,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000,
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "4.56.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }

# %%
print("TARGET")
print("head_dim:", large_model.config.head_dim)
print("num_attention_heads:", large_model.config.num_attention_heads)
print("num_key_value_heads:", large_model.config.num_key_value_heads)
#print("rope_parameters:", large_model.config.rope_parameters)
print(large_model.model.rotary_emb)
# Out:
# TARGET
# head_dim: 128
# num_attention_heads: 32
# num_key_value_heads: 8
# Qwen3RotaryEmbedding()

# %%
print("head_dim:", small_model.config.head_dim)
print("num_attention_heads:", small_model.config.num_attention_heads)
print("num_key_value_heads:", small_model.config.num_key_value_heads)

print("rotary_scaling:", getattr(small_model.config, "rope_scaling", None))
#print("rope_parameters:", small_model.config.rope_parameters)

print("\nAttention module:")
print(small_model.model.layers[0].self_attn)

print("\nRoPE module:")
print(small_model.model.rotary_emb)
# Out:
# head_dim: 128
# num_attention_heads: 16
# num_key_value_heads: 8
# rotary_scaling: None
#
# Attention module:
# Qwen3Attention(
#   (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#   (k_proj): Linear(in_features=2048, out_features=1024, bias=False)
#   (v_proj): Linear(in_features=2048, out_features=1024, bias=False)
#   (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#   (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#   (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
# )
#
# RoPE module:
# Qwen3RotaryEmbedding()

# %%
import inspect

print(inspect.signature(small_model.model.rotary_emb.forward))
# Out:
# (x, position_ids)

# %%
print(inspect.getsource(small_model.model.rotary_emb.forward))
# Out:
#     @torch.no_grad()
#     @dynamic_rope_update  # power user: used with advanced RoPE types (e.g. dynamic rope)
#     def forward(self, x, position_ids):
#         inv_freq_expanded = self.inv_freq[None, :, None].float().expand(position_ids.shape[0], -1, 1).to(x.device)
#         position_ids_expanded = position_ids[:, None, :].float()
#
#         device_type = x.device.type if isinstance(x.device.type, str) and x.device.type != "mps" else "cpu"
#         with torch.autocast(device_type=device_type, enabled=False):  # Force float32
#             freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(1, 2)
#             emb = torch.cat((freqs, freqs), dim=-1)
#             cos = emb.cos() * self.attention_scaling
#             sin = emb.sin() * self.attention_scaling
#
#         return cos.to(dtype=x.dtype), sin.to(dtype=x.dtype)

# %%
import inspect

print(inspect.getsource(
    small_model.model.layers[0].self_attn.forward
))
# Out:
#     @deprecate_kwarg("past_key_value", new_name="past_key_values", version="4.58")
#     def forward(
#         self,
#         hidden_states: torch.Tensor,
#         position_embeddings: tuple[torch.Tensor, torch.Tensor],
#         attention_mask: Optional[torch.Tensor],
#         past_key_values: Optional[Cache] = None,
#         cache_position: Optional[torch.LongTensor] = None,
#         **kwargs: Unpack[FlashAttentionKwargs],
#     ) -> tuple[torch.Tensor, Optional[torch.Tensor]]:
#         input_shape = hidden_states.shape[:-1]
#         hidden_shape = (*input_shape, -1, self.head_dim)
#
#         query_states = self.q_norm(self.q_proj(hidden_states).view(hidden_shape)).transpose(1, 2)
#         key_states = self.k_norm(self.k_proj(hidden_states).view(hidden_shape)).transpose(1, 2)
#         value_states = self.v_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#
#         cos, sin = position_embeddings
#         query_states, key_states = apply_rotary_pos_emb(query_states, key_states, cos, sin)
#
#         if past_key_values is not None:
#             # sin and cos are specific to RoPE models; cache_position needed for the static cache
#             cache_kwargs = {"sin": sin, "cos": cos, "cache_position": cache_position}
#             key_states, value_states = past_key_values.update(key_states, value_states, self.layer_idx, cache_kwargs)
#
#         attention_interface: Callable = eager_attention_forward
#         if self.config._attn_implementation != "eager":
#             attention_interface = ALL_ATTENTION_FUNCTIONS[self.config._attn_implementation]
#
#         attn_output, attn_weights = attention_interface(
#             self,
#             query_states,
#             key_states,
#             value_states,
#             attention_mask,
#             dropout=0.0 if not self.training else self.attention_dropout,
#             scaling=self.scaling,
#             sliding_window=self.sliding_window,  # diff with Llama
#             **kwargs,
#         )
#
#         attn_output = attn_output.reshape(*input_shape, -1).contiguous()
#         attn_output = self.o_proj(attn_output)
#         return attn_output, attn_weights

# %%
sequences = []

for example in ds:
    ids = small_tokenizer(
        example["text"],
        add_special_tokens=False,
    )["input_ids"]

    if len(ids) >= 1024:
        sequences.append(ids[:1024])

    if len(sequences) == 500:
        break

# %%
print(len(sequences))
# Out:
# 500

# %%
import torch

stride = 4
batch_size = 4

source_kv = []
target_kv = []

sequences = sequences[:100]

source_raw_k = {}
target_raw_k = {}


def make_k_hook(storage, layer_idx):
    def hook(module, inputs, output):
        storage[layer_idx] = output.detach().transpose(1, 2)  # -> (batch, n_kv_heads, seq, head_dim)
    return hook
source_hooks = []
target_hooks = []

for layer in range(28):
    hook = small_model.model.layers[layer].self_attn.k_norm.register_forward_hook(
        make_k_hook(source_raw_k, layer)
    )
    source_hooks.append(hook)

for layer in range(36):
    hook = large_model.model.layers[layer].self_attn.k_norm.register_forward_hook(
        make_k_hook(target_raw_k, layer)
    )
    target_hooks.append(hook)

for start in range(0, len(sequences), batch_size):
    print(start)

    batch_sequences = sequences[start:start + batch_size]

    input_ids = torch.tensor(
        batch_sequences,
        dtype=torch.long
    )

    source_raw_k.clear()
    target_raw_k.clear()

    with torch.no_grad():

        source_outputs = small_model(
            input_ids=input_ids.to(small_model.device),
            use_cache=True,
        )

        target_outputs = large_model(
            input_ids=input_ids.to(large_model.device),
            use_cache=True,
        )

    batch_size_actual = len(batch_sequences)

    for b in range(batch_size_actual):

        source_seq = []
        target_seq = []

        for layer in range(28):

            source_k = source_raw_k[layer][b, :, ::stride, :]
            source_v = source_outputs.past_key_values.layers[layer].values[
                b, :, ::stride, :
            ]

            source_seq.append((
                source_k.float().cpu(),
                source_v.float().cpu()
            ))

        for layer in range(36):

            target_k = target_raw_k[layer][b, :, ::stride, :]
            target_v = target_outputs.past_key_values.layers[layer].values[
                b, :, ::stride, :
            ]

            target_seq.append((
                target_k.float().cpu(),
                target_v.float().cpu()
            ))

        source_kv.append(source_seq)
        target_kv.append(target_seq)

    del source_outputs
    del target_outputs

for hook in source_hooks:
    hook.remove()

for hook in target_hooks:
    hook.remove()
# Out:
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96

# %%
import torch

num_source_layers = 28
num_target_layers = 36
num_heads = 8

r2_matrix = torch.zeros(
    num_source_layers,
    num_target_layers
)

for source_layer in range(num_source_layers):

    for target_layer in range(num_target_layers):

        head_r2 = []

        for head in range(num_heads):

            all_X = []
            all_Y = []

            for i in range(100):

                X = source_kv[i][source_layer][0][head]
                Y = target_kv[i][target_layer][0][head]

                all_X.append(X)
                all_Y.append(Y)

            X = torch.cat(all_X, dim=0)
            Y = torch.cat(all_Y, dim=0)

            X_aug = torch.cat(
                [
                    X,
                    torch.ones(X.shape[0], 1)
                ],
                dim=1
            )

            solution = torch.linalg.lstsq(
                X_aug,
                Y
            ).solution

            W_k = solution[:-1]
            b_k = solution[-1]

            Y_pred = X @ W_k + b_k

            ss_res = torch.sum(
                (Y - Y_pred) ** 2
            )

            
            ss_tot = ((Y - Y.mean(dim=0, keepdim=True)) ** 2).sum()

            r2 = 1 - ss_res / ss_tot

            head_r2.append(r2.item())

        mean_r2 = sum(head_r2) / len(head_r2)

        r2_matrix[source_layer, target_layer] = mean_r2
# Out:
# Source  0 → Target  0: 0.9944
# Source  0 → Target  1: 0.9738
# Source  0 → Target  2: 0.9291
# Source  0 → Target  3: 0.9632
# Source  0 → Target  4: 0.9475
# Source  0 → Target  5: 0.9514
# Source  0 → Target  6: 0.9493
# Source  0 → Target  7: 0.9316
# Source  0 → Target  8: 0.9551
# Source  0 → Target  9: 0.8835
# Source  0 → Target 10: 0.9752
# Source  0 → Target 11: 0.9528
# Source  0 → Target 12: 0.9692
# Source  0 → Target 13: 0.8659
# Source  0 → Target 14: 0.9551
# Source  0 → Target 15: 0.8935
# Source  0 → Target 16: 0.9015
# Source  0 → Target 17: 0.9049
# Source  0 → Target 18: 0.9226
# Source  0 → Target 19: 0.9274
# Source  0 → Target 20: 0.8992
# Source  0 → Target 21: 0.9395
# Source  0 → Target 22: 0.9421
# Source  0 → Target 23: 0.9632
# Source  0 → Target 24: 0.9240
# Source  0 → Target 25: 0.9375
# Source  0 → Target 26: 0.9157
# Source  0 → Target 27: 0.9114
# Source  0 → Target 28: 0.8953
# Source  0 → Target 29: 0.9058
# Source  0 → Target 30: 0.9512
# Source  0 → Target 31: 0.9244
# Source  0 → Target 32: 0.9160
# Source  0 → Target 33: 0.8962
# Source  0 → Target 34: 0.9183
# Source  0 → Target 35: 0.9770
# Source  1 → Target  0: 0.9929
# Source  1 → Target  1: 0.9754
# Source  1 → Target  2: 0.9361
# Source  1 → Target  3: 0.9674
# Source  1 → Target  4: 0.9505
# Source  1 → Target  5: 0.9576
# Source  1 → Target  6: 0.9579
# Source  1 → Target  7: 0.9346
# Source  1 → Target  8: 0.9574
# Source  1 → Target  9: 0.8917
# Source  1 → Target 10: 0.9757
# Source  1 → Target 11: 0.9558
# Source  1 → Target 12: 0.9717
# Source  1 → Target 13: 0.8751
# Source  1 → Target 14: 0.9584
# Source  1 → Target 15: 0.8992
# Source  1 → Target 16: 0.9037
# Source  1 → Target 17: 0.9124
# Source  1 → Target 18: 0.9268
# Source  1 → Target 19: 0.9345
# Source  1 → Target 20: 0.9067
# Source  1 → Target 21: 0.9430
# Source  1 → Target 22: 0.9471
# Source  1 → Target 23: 0.9652
# Source  1 → Target 24: 0.9324
# Source  1 → Target 25: 0.9399
# Source  1 → Target 26: 0.9227
# Source  1 → Target 27: 0.9177
# Source  1 → Target 28: 0.9003
# Source  1 → Target 29: 0.9131
# Source  1 → Target 30: 0.9532
# Source  1 → Target 31: 0.9260
# Source  1 → Target 32: 0.9210
# Source  1 → Target 33: 0.9026
# Source  1 → Target 34: 0.9220
# Source  1 → Target 35: 0.9761
# Source  2 → Target  0: 0.9915
# Source  2 → Target  1: 0.9706
# Source  2 → Target  2: 0.9149
# Source  2 → Target  3: 0.9632
# Source  2 → Target  4: 0.9335
# Source  2 → Target  5: 0.9405
# Source  2 → Target  6: 0.9547
# Source  2 → Target  7: 0.9196
# Source  2 → Target  8: 0.9488
# Source  2 → Target  9: 0.8816
# Source  2 → Target 10: 0.9707
# Source  2 → Target 11: 0.9436
# Source  2 → Target 12: 0.9672
# Source  2 → Target 13: 0.8592
# Source  2 → Target 14: 0.9511
# Source  2 → Target 15: 0.8841
# Source  2 → Target 16: 0.8942
# Source  2 → Target 17: 0.8997
# Source  2 → Target 18: 0.9217
# Source  2 → Target 19: 0.9293
# Source  2 → Target 20: 0.9088
# Source  2 → Target 21: 0.9420
# Source  2 → Target 22: 0.9401
# Source  2 → Target 23: 0.9603
# Source  2 → Target 24: 0.9188
# Source  2 → Target 25: 0.9157
# Source  2 → Target 26: 0.9269
# Source  2 → Target 27: 0.9070
# Source  2 → Target 28: 0.8812
# Source  2 → Target 29: 0.8949
# Source  2 → Target 30: 0.9407
# Source  2 → Target 31: 0.9029
# Source  2 → Target 32: 0.8931
# Source  2 → Target 33: 0.8731
# Source  2 → Target 34: 0.8945
# Source  2 → Target 35: 0.9703
# Source  3 → Target  0: 0.9421
# Source  3 → Target  1: 0.8696
# Source  3 → Target  2: 0.7536
# Source  3 → Target  3: 0.8571
# Source  3 → Target  4: 0.8160
# Source  3 → Target  5: 0.8625
# Source  3 → Target  6: 0.8165
# Source  3 → Target  7: 0.7483
# Source  3 → Target  8: 0.8450
# Source  3 → Target  9: 0.6220
# Source  3 → Target 10: 0.9056
# Source  3 → Target 11: 0.8620
# Source  3 → Target 12: 0.8842
# Source  3 → Target 13: 0.6273
# Source  3 → Target 14: 0.8424
# Source  3 → Target 15: 0.6619
# Source  3 → Target 16: 0.7014
# Source  3 → Target 17: 0.7014
# Source  3 → Target 18: 0.7486
# Source  3 → Target 19: 0.7712
# Source  3 → Target 20: 0.6743
# Source  3 → Target 21: 0.8019
# Source  3 → Target 22: 0.8058
# Source  3 → Target 23: 0.8833
# Source  3 → Target 24: 0.7336
# Source  3 → Target 25: 0.7717
# Source  3 → Target 26: 0.7141
# Source  3 → Target 27: 0.6968
# Source  3 → Target 28: 0.6282
# Source  3 → Target 29: 0.7030
# Source  3 → Target 30: 0.8242
# Source  3 → Target 31: 0.7317
# Source  3 → Target 32: 0.6908
# Source  3 → Target 33: 0.6178
# Source  3 → Target 34: 0.6961
# Source  3 → Target 35: 0.8981
# Source  4 → Target  0: 0.9642
# Source  4 → Target  1: 0.8889
# Source  4 → Target  2: 0.7905
# Source  4 → Target  3: 0.8911
# Source  4 → Target  4: 0.8405
# Source  4 → Target  5: 0.8582
# Source  4 → Target  6: 0.8391
# Source  4 → Target  7: 0.7999
# Source  4 → Target  8: 0.8701
# Source  4 → Target  9: 0.7228
# Source  4 → Target 10: 0.9262
# Source  4 → Target 11: 0.8744
# Source  4 → Target 12: 0.9085
# Source  4 → Target 13: 0.6719
# Source  4 → Target 14: 0.8802
# Source  4 → Target 15: 0.7338
# Source  4 → Target 16: 0.7321
# Source  4 → Target 17: 0.7427
# Source  4 → Target 18: 0.8017
# Source  4 → Target 19: 0.7865
# Source  4 → Target 20: 0.7544
# Source  4 → Target 21: 0.8648
# Source  4 → Target 22: 0.8396
# Source  4 → Target 23: 0.9010
# Source  4 → Target 24: 0.7698
# Source  4 → Target 25: 0.8280
# Source  4 → Target 26: 0.7754
# Source  4 → Target 27: 0.8043
# Source  4 → Target 28: 0.6872
# Source  4 → Target 29: 0.7178
# Source  4 → Target 30: 0.8777
# Source  4 → Target 31: 0.7696
# Source  4 → Target 32: 0.7166
# Source  4 → Target 33: 0.6896
# Source  4 → Target 34: 0.7708
# Source  4 → Target 35: 0.9378
# Source  5 → Target  0: 0.9684
# Source  5 → Target  1: 0.9108
# Source  5 → Target  2: 0.8284
# Source  5 → Target  3: 0.9014
# Source  5 → Target  4: 0.8714
# Source  5 → Target  5: 0.9003
# Source  5 → Target  6: 0.8733
# Source  5 → Target  7: 0.8421
# Source  5 → Target  8: 0.8920
# Source  5 → Target  9: 0.7308
# Source  5 → Target 10: 0.9541
# Source  5 → Target 11: 0.8864
# Source  5 → Target 12: 0.9323
# Source  5 → Target 13: 0.7195
# Source  5 → Target 14: 0.8945
# Source  5 → Target 15: 0.7855
# Source  5 → Target 16: 0.8133
# Source  5 → Target 17: 0.8415
# Source  5 → Target 18: 0.8359
# Source  5 → Target 19: 0.8553
# Source  5 → Target 20: 0.7728
# Source  5 → Target 21: 0.8724
# Source  5 → Target 22: 0.8593
# Source  5 → Target 23: 0.9254
# Source  5 → Target 24: 0.8200
# Source  5 → Target 25: 0.8824
# Source  5 → Target 26: 0.8180
# Source  5 → Target 27: 0.8081
# Source  5 → Target 28: 0.7489
# Source  5 → Target 29: 0.7822
# Source  5 → Target 30: 0.8810
# Source  5 → Target 31: 0.8308
# Source  5 → Target 32: 0.8208
# Source  5 → Target 33: 0.7647
# Source  5 → Target 34: 0.8381
# Source  5 → Target 35: 0.9376
# Source  6 → Target  0: 0.9668
# Source  6 → Target  1: 0.9173
# Source  6 → Target  2: 0.8176
# Source  6 → Target  3: 0.9119
# Source  6 → Target  4: 0.8934
# Source  6 → Target  5: 0.8929
# Source  6 → Target  6: 0.8970
# Source  6 → Target  7: 0.8675
# Source  6 → Target  8: 0.9206
# Source  6 → Target  9: 0.7769
# Source  6 → Target 10: 0.9538
# Source  6 → Target 11: 0.9227
# Source  6 → Target 12: 0.9470
# Source  6 → Target 13: 0.7738
# Source  6 → Target 14: 0.9228
# Source  6 → Target 15: 0.8230
# Source  6 → Target 16: 0.8455
# Source  6 → Target 17: 0.8582
# Source  6 → Target 18: 0.8655
# Source  6 → Target 19: 0.8995
# Source  6 → Target 20: 0.8498
# Source  6 → Target 21: 0.8994
# Source  6 → Target 22: 0.9161
# Source  6 → Target 23: 0.9429
# Source  6 → Target 24: 0.8814
# Source  6 → Target 25: 0.8593
# Source  6 → Target 26: 0.8555
# Source  6 → Target 27: 0.8521
# Source  6 → Target 28: 0.7822
# Source  6 → Target 29: 0.8293
# Source  6 → Target 30: 0.9075
# Source  6 → Target 31: 0.8519
# Source  6 → Target 32: 0.8265
# Source  6 → Target 33: 0.8102
# Source  6 → Target 34: 0.8625
# Source  6 → Target 35: 0.9455
# Source  7 → Target  0: 0.9502
# Source  7 → Target  1: 0.8871
# Source  7 → Target  2: 0.7658
# Source  7 → Target  3: 0.8800
# Source  7 → Target  4: 0.8324
# Source  7 → Target  5: 0.8570
# Source  7 → Target  6: 0.8631
# Source  7 → Target  7: 0.7962
# Source  7 → Target  8: 0.8775
# Source  7 → Target  9: 0.6786
# Source  7 → Target 10: 0.9263
# Source  7 → Target 11: 0.8731
# Source  7 → Target 12: 0.9231
# Source  7 → Target 13: 0.6973
# Source  7 → Target 14: 0.8813
# Source  7 → Target 15: 0.7468
# Source  7 → Target 16: 0.7546
# Source  7 → Target 17: 0.7535
# Source  7 → Target 18: 0.8060
# Source  7 → Target 19: 0.8255
# Source  7 → Target 20: 0.7526
# Source  7 → Target 21: 0.8490
# Source  7 → Target 22: 0.8536
# Source  7 → Target 23: 0.9163
# Source  7 → Target 24: 0.7999
# Source  7 → Target 25: 0.8260
# Source  7 → Target 26: 0.7810
# Source  7 → Target 27: 0.7583
# Source  7 → Target 28: 0.7148
# Source  7 → Target 29: 0.7592
# Source  7 → Target 30: 0.8568
# Source  7 → Target 31: 0.7792
# Source  7 → Target 32: 0.7523
# Source  7 → Target 33: 0.6914
# Source  7 → Target 34: 0.8206
# Source  7 → Target 35: 0.9222
# Source  8 → Target  0: 0.9387
# Source  8 → Target  1: 0.8939
# Source  8 → Target  2: 0.7681
# Source  8 → Target  3: 0.8863
# Source  8 → Target  4: 0.8161
# Source  8 → Target  5: 0.8448
# Source  8 → Target  6: 0.8245
# Source  8 → Target  7: 0.7961
# Source  8 → Target  8: 0.8985
# Source  8 → Target  9: 0.7325
# Source  8 → Target 10: 0.9187
# Source  8 → Target 11: 0.8492
# Source  8 → Target 12: 0.9158
# Source  8 → Target 13: 0.7138
# Source  8 → Target 14: 0.8866
# Source  8 → Target 15: 0.7349
# Source  8 → Target 16: 0.8197
# Source  8 → Target 17: 0.7656
# Source  8 → Target 18: 0.8030
# Source  8 → Target 19: 0.8441
# Source  8 → Target 20: 0.6807
# Source  8 → Target 21: 0.8395
# Source  8 → Target 22: 0.8419
# Source  8 → Target 23: 0.8866
# Source  8 → Target 24: 0.8048
# Source  8 → Target 25: 0.8280
# Source  8 → Target 26: 0.7704
# Source  8 → Target 27: 0.7647
# Source  8 → Target 28: 0.7401
# Source  8 → Target 29: 0.7548
# Source  8 → Target 30: 0.8952
# Source  8 → Target 31: 0.7851
# Source  8 → Target 32: 0.8042
# Source  8 → Target 33: 0.7382
# Source  8 → Target 34: 0.7612
# Source  8 → Target 35: 0.9143
# Source  9 → Target  0: 0.8938
# Source  9 → Target  1: 0.8432
# Source  9 → Target  2: 0.6907
# Source  9 → Target  3: 0.8233
# Source  9 → Target  4: 0.7924
# Source  9 → Target  5: 0.8153
# Source  9 → Target  6: 0.7805
# Source  9 → Target  7: 0.7330
# Source  9 → Target  8: 0.8233
# Source  9 → Target  9: 0.6949
# Source  9 → Target 10: 0.8588
# Source  9 → Target 11: 0.8095
# Source  9 → Target 12: 0.8637
# Source  9 → Target 13: 0.5972
# Source  9 → Target 14: 0.8213
# Source  9 → Target 15: 0.7106
# Source  9 → Target 16: 0.7149
# Source  9 → Target 17: 0.6906
# Source  9 → Target 18: 0.7488
# Source  9 → Target 19: 0.7819
# Source  9 → Target 20: 0.6756
# Source  9 → Target 21: 0.7937
# Source  9 → Target 22: 0.8094
# Source  9 → Target 23: 0.8441
# Source  9 → Target 24: 0.7140
# Source  9 → Target 25: 0.7440
# Source  9 → Target 26: 0.6971
# Source  9 → Target 27: 0.6694
# Source  9 → Target 28: 0.6566
# Source  9 → Target 29: 0.6365
# Source  9 → Target 30: 0.7955
# Source  9 → Target 31: 0.7274
# Source  9 → Target 32: 0.6696
# Source  9 → Target 33: 0.5842
# Source  9 → Target 34: 0.6599
# Source  9 → Target 35: 0.8596
# Source 10 → Target  0: 0.9513
# Source 10 → Target  1: 0.8796
# Source 10 → Target  2: 0.7524
# Source 10 → Target  3: 0.8767
# Source 10 → Target  4: 0.8191
# Source 10 → Target  5: 0.8468
# Source 10 → Target  6: 0.8337
# Source 10 → Target  7: 0.7835
# Source 10 → Target  8: 0.8695
# Source 10 → Target  9: 0.6671
# Source 10 → Target 10: 0.9220
# Source 10 → Target 11: 0.8679
# Source 10 → Target 12: 0.9107
# Source 10 → Target 13: 0.6503
# Source 10 → Target 14: 0.8791
# Source 10 → Target 15: 0.7165
# Source 10 → Target 16: 0.7495
# Source 10 → Target 17: 0.7500
# Source 10 → Target 18: 0.7991
# Source 10 → Target 19: 0.8089
# Source 10 → Target 20: 0.7397
# Source 10 → Target 21: 0.8463
# Source 10 → Target 22: 0.8440
# Source 10 → Target 23: 0.8989
# Source 10 → Target 24: 0.7807
# Source 10 → Target 25: 0.8089
# Source 10 → Target 26: 0.7693
# Source 10 → Target 27: 0.7528
# Source 10 → Target 28: 0.6947
# Source 10 → Target 29: 0.7444
# Source 10 → Target 30: 0.8589
# Source 10 → Target 31: 0.7709
# Source 10 → Target 32: 0.7586
# Source 10 → Target 33: 0.6786
# Source 10 → Target 34: 0.7459
# Source 10 → Target 35: 0.9273
# Source 11 → Target  0: 0.9566
# Source 11 → Target  1: 0.8751
# Source 11 → Target  2: 0.7457
# Source 11 → Target  3: 0.8705
# Source 11 → Target  4: 0.8137
# Source 11 → Target  5: 0.8420
# Source 11 → Target  6: 0.8317
# Source 11 → Target  7: 0.7772
# Source 11 → Target  8: 0.8814
# Source 11 → Target  9: 0.6586
# Source 11 → Target 10: 0.9215
# Source 11 → Target 11: 0.8654
# Source 11 → Target 12: 0.9110
# Source 11 → Target 13: 0.7010
# Source 11 → Target 14: 0.8717
# Source 11 → Target 15: 0.7139
# Source 11 → Target 16: 0.7689
# Source 11 → Target 17: 0.7591
# Source 11 → Target 18: 0.7927
# Source 11 → Target 19: 0.8323
# Source 11 → Target 20: 0.7409
# Source 11 → Target 21: 0.8333
# Source 11 → Target 22: 0.8473
# Source 11 → Target 23: 0.8900
# Source 11 → Target 24: 0.7782
# Source 11 → Target 25: 0.8168
# Source 11 → Target 26: 0.7591
# Source 11 → Target 27: 0.7357
# Source 11 → Target 28: 0.7024
# Source 11 → Target 29: 0.7214
# Source 11 → Target 30: 0.8516
# Source 11 → Target 31: 0.7712
# Source 11 → Target 32: 0.7483
# Source 11 → Target 33: 0.7019
# Source 11 → Target 34: 0.7460
# Source 11 → Target 35: 0.9123
# Source 12 → Target  0: 0.9225
# Source 12 → Target  1: 0.8685
# Source 12 → Target  2: 0.7256
# Source 12 → Target  3: 0.8739
# Source 12 → Target  4: 0.8105
# Source 12 → Target  5: 0.8512
# Source 12 → Target  6: 0.8207
# Source 12 → Target  7: 0.7994
# Source 12 → Target  8: 0.8718
# Source 12 → Target  9: 0.6731
# Source 12 → Target 10: 0.9344
# Source 12 → Target 11: 0.8593
# Source 12 → Target 12: 0.9211
# Source 12 → Target 13: 0.6770
# Source 12 → Target 14: 0.8829
# Source 12 → Target 15: 0.7255
# Source 12 → Target 16: 0.7774
# Source 12 → Target 17: 0.7659
# Source 12 → Target 18: 0.8303
# Source 12 → Target 19: 0.8182
# Source 12 → Target 20: 0.7573
# Source 12 → Target 21: 0.8661
# Source 12 → Target 22: 0.8448
# Source 12 → Target 23: 0.8923
# Source 12 → Target 24: 0.7987
# Source 12 → Target 25: 0.8066
# Source 12 → Target 26: 0.7756
# Source 12 → Target 27: 0.7531
# Source 12 → Target 28: 0.7375
# Source 12 → Target 29: 0.7867
# Source 12 → Target 30: 0.8719
# Source 12 → Target 31: 0.7663
# Source 12 → Target 32: 0.7572
# Source 12 → Target 33: 0.6805
# Source 12 → Target 34: 0.7764
# Source 12 → Target 35: 0.9092
# Source 13 → Target  0: 0.9495
# Source 13 → Target  1: 0.8885
# Source 13 → Target  2: 0.7972
# Source 13 → Target  3: 0.8841
# Source 13 → Target  4: 0.8290
# Source 13 → Target  5: 0.8605
# Source 13 → Target  6: 0.8658
# Source 13 → Target  7: 0.8231
# Source 13 → Target  8: 0.8881
# Source 13 → Target  9: 0.7021
# Source 13 → Target 10: 0.9348
# Source 13 → Target 11: 0.8851
# Source 13 → Target 12: 0.9334
# Source 13 → Target 13: 0.7257
# Source 13 → Target 14: 0.8965
# Source 13 → Target 15: 0.7612
# Source 13 → Target 16: 0.8118
# Source 13 → Target 17: 0.8235
# Source 13 → Target 18: 0.8312
# Source 13 → Target 19: 0.8613
# Source 13 → Target 20: 0.7956
# Source 13 → Target 21: 0.8563
# Source 13 → Target 22: 0.8768
# Source 13 → Target 23: 0.9081
# Source 13 → Target 24: 0.8283
# Source 13 → Target 25: 0.8331
# Source 13 → Target 26: 0.7979
# Source 13 → Target 27: 0.7708
# Source 13 → Target 28: 0.7556
# Source 13 → Target 29: 0.7847
# Source 13 → Target 30: 0.8742
# Source 13 → Target 31: 0.8283
# Source 13 → Target 32: 0.7967
# Source 13 → Target 33: 0.7160
# Source 13 → Target 34: 0.7923
# Source 13 → Target 35: 0.9243
# Source 14 → Target  0: 0.9390
# Source 14 → Target  1: 0.8737
# Source 14 → Target  2: 0.7489
# Source 14 → Target  3: 0.8546
# Source 14 → Target  4: 0.7987
# Source 14 → Target  5: 0.8237
# Source 14 → Target  6: 0.8406
# Source 14 → Target  7: 0.7480
# Source 14 → Target  8: 0.8684
# Source 14 → Target  9: 0.6278
# Source 14 → Target 10: 0.9183
# Source 14 → Target 11: 0.8498
# Source 14 → Target 12: 0.9088
# Source 14 → Target 13: 0.6256
# Source 14 → Target 14: 0.8822
# Source 14 → Target 15: 0.7705
# Source 14 → Target 16: 0.7412
# Source 14 → Target 17: 0.7843
# Source 14 → Target 18: 0.7722
# Source 14 → Target 19: 0.8171
# Source 14 → Target 20: 0.7101
# Source 14 → Target 21: 0.8149
# Source 14 → Target 22: 0.8430
# Source 14 → Target 23: 0.9069
# Source 14 → Target 24: 0.7781
# Source 14 → Target 25: 0.7846
# Source 14 → Target 26: 0.7583
# Source 14 → Target 27: 0.7129
# Source 14 → Target 28: 0.7302
# Source 14 → Target 29: 0.7429
# Source 14 → Target 30: 0.8339
# Source 14 → Target 31: 0.7629
# Source 14 → Target 32: 0.7677
# Source 14 → Target 33: 0.6983
# Source 14 → Target 34: 0.7147
# Source 14 → Target 35: 0.9108
# Source 15 → Target  0: 0.9589
# Source 15 → Target  1: 0.9101
# Source 15 → Target  2: 0.8162
# Source 15 → Target  3: 0.9059
# Source 15 → Target  4: 0.8704
# Source 15 → Target  5: 0.8836
# Source 15 → Target  6: 0.8791
# Source 15 → Target  7: 0.8385
# Source 15 → Target  8: 0.9239
# Source 15 → Target  9: 0.7510
# Source 15 → Target 10: 0.9462
# Source 15 → Target 11: 0.9219
# Source 15 → Target 12: 0.9487
# Source 15 → Target 13: 0.7863
# Source 15 → Target 14: 0.9184
# Source 15 → Target 15: 0.8036
# Source 15 → Target 16: 0.8677
# Source 15 → Target 17: 0.8448
# Source 15 → Target 18: 0.8682
# Source 15 → Target 19: 0.8934
# Source 15 → Target 20: 0.8485
# Source 15 → Target 21: 0.9051
# Source 15 → Target 22: 0.9061
# Source 15 → Target 23: 0.9341
# Source 15 → Target 24: 0.8625
# Source 15 → Target 25: 0.8623
# Source 15 → Target 26: 0.8409
# Source 15 → Target 27: 0.8334
# Source 15 → Target 28: 0.8158
# Source 15 → Target 29: 0.8070
# Source 15 → Target 30: 0.8976
# Source 15 → Target 31: 0.8440
# Source 15 → Target 32: 0.8444
# Source 15 → Target 33: 0.7681
# Source 15 → Target 34: 0.8451
# Source 15 → Target 35: 0.9444
# Source 16 → Target  0: 0.9828
# Source 16 → Target  1: 0.9592
# Source 16 → Target  2: 0.9170
# Source 16 → Target  3: 0.9609
# Source 16 → Target  4: 0.9370
# Source 16 → Target  5: 0.9477
# Source 16 → Target  6: 0.9438
# Source 16 → Target  7: 0.9330
# Source 16 → Target  8: 0.9620
# Source 16 → Target  9: 0.9009
# Source 16 → Target 10: 0.9787
# Source 16 → Target 11: 0.9629
# Source 16 → Target 12: 0.9789
# Source 16 → Target 13: 0.9063
# Source 16 → Target 14: 0.9689
# Source 16 → Target 15: 0.9274
# Source 16 → Target 16: 0.9342
# Source 16 → Target 17: 0.9350
# Source 16 → Target 18: 0.9539
# Source 16 → Target 19: 0.9521
# Source 16 → Target 20: 0.9403
# Source 16 → Target 21: 0.9642
# Source 16 → Target 22: 0.9605
# Source 16 → Target 23: 0.9722
# Source 16 → Target 24: 0.9471
# Source 16 → Target 25: 0.9449
# Source 16 → Target 26: 0.9416
# Source 16 → Target 27: 0.9360
# Source 16 → Target 28: 0.9213
# Source 16 → Target 29: 0.9216
# Source 16 → Target 30: 0.9583
# Source 16 → Target 31: 0.9324
# Source 16 → Target 32: 0.9256
# Source 16 → Target 33: 0.9068
# Source 16 → Target 34: 0.9324
# Source 16 → Target 35: 0.9771
# Source 17 → Target  0: 0.9836
# Source 17 → Target  1: 0.9570
# Source 17 → Target  2: 0.9080
# Source 17 → Target  3: 0.9598
# Source 17 → Target  4: 0.9369
# Source 17 → Target  5: 0.9476
# Source 17 → Target  6: 0.9431
# Source 17 → Target  7: 0.9316
# Source 17 → Target  8: 0.9614
# Source 17 → Target  9: 0.8971
# Source 17 → Target 10: 0.9777
# Source 17 → Target 11: 0.9612
# Source 17 → Target 12: 0.9773
# Source 17 → Target 13: 0.9041
# Source 17 → Target 14: 0.9668
# Source 17 → Target 15: 0.9216
# Source 17 → Target 16: 0.9340
# Source 17 → Target 17: 0.9254
# Source 17 → Target 18: 0.9484
# Source 17 → Target 19: 0.9511
# Source 17 → Target 20: 0.9344
# Source 17 → Target 21: 0.9606
# Source 17 → Target 22: 0.9593
# Source 17 → Target 23: 0.9704
# Source 17 → Target 24: 0.9432
# Source 17 → Target 25: 0.9427
# Source 17 → Target 26: 0.9372
# Source 17 → Target 27: 0.9306
# Source 17 → Target 28: 0.9197
# Source 17 → Target 29: 0.9215
# Source 17 → Target 30: 0.9561
# Source 17 → Target 31: 0.9306
# Source 17 → Target 32: 0.9245
# Source 17 → Target 33: 0.9016
# Source 17 → Target 34: 0.9287
# Source 17 → Target 35: 0.9756
# Source 18 → Target  0: 0.9862
# Source 18 → Target  1: 0.9614
# Source 18 → Target  2: 0.9242
# Source 18 → Target  3: 0.9655
# Source 18 → Target  4: 0.9434
# Source 18 → Target  5: 0.9530
# Source 18 → Target  6: 0.9472
# Source 18 → Target  7: 0.9387
# Source 18 → Target  8: 0.9612
# Source 18 → Target  9: 0.8978
# Source 18 → Target 10: 0.9774
# Source 18 → Target 11: 0.9597
# Source 18 → Target 12: 0.9757
# Source 18 → Target 13: 0.8898
# Source 18 → Target 14: 0.9642
# Source 18 → Target 15: 0.9116
# Source 18 → Target 16: 0.9229
# Source 18 → Target 17: 0.9235
# Source 18 → Target 18: 0.9405
# Source 18 → Target 19: 0.9423
# Source 18 → Target 20: 0.9210
# Source 18 → Target 21: 0.9571
# Source 18 → Target 22: 0.9580
# Source 18 → Target 23: 0.9746
# Source 18 → Target 24: 0.9397
# Source 18 → Target 25: 0.9491
# Source 18 → Target 26: 0.9364
# Source 18 → Target 27: 0.9285
# Source 18 → Target 28: 0.9130
# Source 18 → Target 29: 0.9153
# Source 18 → Target 30: 0.9575
# Source 18 → Target 31: 0.9353
# Source 18 → Target 32: 0.9230
# Source 18 → Target 33: 0.9060
# Source 18 → Target 34: 0.9335
# Source 18 → Target 35: 0.9792
# Source 19 → Target  0: 0.9849
# Source 19 → Target  1: 0.9601
# Source 19 → Target  2: 0.9261
# Source 19 → Target  3: 0.9659
# Source 19 → Target  4: 0.9415
# Source 19 → Target  5: 0.9536
# Source 19 → Target  6: 0.9498
# Source 19 → Target  7: 0.9384
# Source 19 → Target  8: 0.9638
# Source 19 → Target  9: 0.9034
# Source 19 → Target 10: 0.9779
# Source 19 → Target 11: 0.9606
# Source 19 → Target 12: 0.9771
# Source 19 → Target 13: 0.8946
# Source 19 → Target 14: 0.9666
# Source 19 → Target 15: 0.9170
# Source 19 → Target 16: 0.9291
# Source 19 → Target 17: 0.9264
# Source 19 → Target 18: 0.9451
# Source 19 → Target 19: 0.9457
# Source 19 → Target 20: 0.9289
# Source 19 → Target 21: 0.9608
# Source 19 → Target 22: 0.9588
# Source 19 → Target 23: 0.9731
# Source 19 → Target 24: 0.9432
# Source 19 → Target 25: 0.9478
# Source 19 → Target 26: 0.9415
# Source 19 → Target 27: 0.9364
# Source 19 → Target 28: 0.9221
# Source 19 → Target 29: 0.9233
# Source 19 → Target 30: 0.9585
# Source 19 → Target 31: 0.9347
# Source 19 → Target 32: 0.9249
# Source 19 → Target 33: 0.9100
# Source 19 → Target 34: 0.9343
# Source 19 → Target 35: 0.9784
# Source 20 → Target  0: 0.9327
# Source 20 → Target  1: 0.8736
# Source 20 → Target  2: 0.7158
# Source 20 → Target  3: 0.8555
# Source 20 → Target  4: 0.7933
# Source 20 → Target  5: 0.8285
# Source 20 → Target  6: 0.8391
# Source 20 → Target  7: 0.7598
# Source 20 → Target  8: 0.8489
# Source 20 → Target  9: 0.6623
# Source 20 → Target 10: 0.9121
# Source 20 → Target 11: 0.8724
# Source 20 → Target 12: 0.8915
# Source 20 → Target 13: 0.6311
# Source 20 → Target 14: 0.8521
# Source 20 → Target 15: 0.7123
# Source 20 → Target 16: 0.7510
# Source 20 → Target 17: 0.7114
# Source 20 → Target 18: 0.7702
# Source 20 → Target 19: 0.8270
# Source 20 → Target 20: 0.7340
# Source 20 → Target 21: 0.8449
# Source 20 → Target 22: 0.8160
# Source 20 → Target 23: 0.8901
# Source 20 → Target 24: 0.7411
# Source 20 → Target 25: 0.7733
# Source 20 → Target 26: 0.7616
# Source 20 → Target 27: 0.7166
# Source 20 → Target 28: 0.7196
# Source 20 → Target 29: 0.6560
# Source 20 → Target 30: 0.8336
# Source 20 → Target 31: 0.7861
# Source 20 → Target 32: 0.7754
# Source 20 → Target 33: 0.6617
# Source 20 → Target 34: 0.6974
# Source 20 → Target 35: 0.9015
# Source 21 → Target  0: 0.9451
# Source 21 → Target  1: 0.8738
# Source 21 → Target  2: 0.7523
# Source 21 → Target  3: 0.8599
# Source 21 → Target  4: 0.7926
# Source 21 → Target  5: 0.8224
# Source 21 → Target  6: 0.8242
# Source 21 → Target  7: 0.7357
# Source 21 → Target  8: 0.8848
# Source 21 → Target  9: 0.6598
# Source 21 → Target 10: 0.9067
# Source 21 → Target 11: 0.8757
# Source 21 → Target 12: 0.9179
# Source 21 → Target 13: 0.6069
# Source 21 → Target 14: 0.8844
# Source 21 → Target 15: 0.7412
# Source 21 → Target 16: 0.7304
# Source 21 → Target 17: 0.7053
# Source 21 → Target 18: 0.7706
# Source 21 → Target 19: 0.7745
# Source 21 → Target 20: 0.7007
# Source 21 → Target 21: 0.8213
# Source 21 → Target 22: 0.8404
# Source 21 → Target 23: 0.8694
# Source 21 → Target 24: 0.7856
# Source 21 → Target 25: 0.7792
# Source 21 → Target 26: 0.7669
# Source 21 → Target 27: 0.7603
# Source 21 → Target 28: 0.7275
# Source 21 → Target 29: 0.7010
# Source 21 → Target 30: 0.8453
# Source 21 → Target 31: 0.7673
# Source 21 → Target 32: 0.7328
# Source 21 → Target 33: 0.7135
# Source 21 → Target 34: 0.7424
# Source 21 → Target 35: 0.9022
# Source 22 → Target  0: 0.9578
# Source 22 → Target  1: 0.9148
# Source 22 → Target  2: 0.7885
# Source 22 → Target  3: 0.8907
# Source 22 → Target  4: 0.8589
# Source 22 → Target  5: 0.8761
# Source 22 → Target  6: 0.8508
# Source 22 → Target  7: 0.8061
# Source 22 → Target  8: 0.8799
# Source 22 → Target  9: 0.7103
# Source 22 → Target 10: 0.9301
# Source 22 → Target 11: 0.8788
# Source 22 → Target 12: 0.9222
# Source 22 → Target 13: 0.6833
# Source 22 → Target 14: 0.9100
# Source 22 → Target 15: 0.7462
# Source 22 → Target 16: 0.7761
# Source 22 → Target 17: 0.7716
# Source 22 → Target 18: 0.8245
# Source 22 → Target 19: 0.8443
# Source 22 → Target 20: 0.7770
# Source 22 → Target 21: 0.8688
# Source 22 → Target 22: 0.8646
# Source 22 → Target 23: 0.9070
# Source 22 → Target 24: 0.8420
# Source 22 → Target 25: 0.8467
# Source 22 → Target 26: 0.8126
# Source 22 → Target 27: 0.7971
# Source 22 → Target 28: 0.7619
# Source 22 → Target 29: 0.7974
# Source 22 → Target 30: 0.8733
# Source 22 → Target 31: 0.8021
# Source 22 → Target 32: 0.7889
# Source 22 → Target 33: 0.7407
# Source 22 → Target 34: 0.7985
# Source 22 → Target 35: 0.9408
# Source 23 → Target  0: 0.9444
# Source 23 → Target  1: 0.8796
# Source 23 → Target  2: 0.7717
# Source 23 → Target  3: 0.8788
# Source 23 → Target  4: 0.8198
# Source 23 → Target  5: 0.8545
# Source 23 → Target  6: 0.8357
# Source 23 → Target  7: 0.7818
# Source 23 → Target  8: 0.8651
# Source 23 → Target  9: 0.6647
# Source 23 → Target 10: 0.9207
# Source 23 → Target 11: 0.8726
# Source 23 → Target 12: 0.9105
# Source 23 → Target 13: 0.7194
# Source 23 → Target 14: 0.8710
# Source 23 → Target 15: 0.7276
# Source 23 → Target 16: 0.7574
# Source 23 → Target 17: 0.7485
# Source 23 → Target 18: 0.7987
# Source 23 → Target 19: 0.8228
# Source 23 → Target 20: 0.7406
# Source 23 → Target 21: 0.8365
# Source 23 → Target 22: 0.8492
# Source 23 → Target 23: 0.9081
# Source 23 → Target 24: 0.8221
# Source 23 → Target 25: 0.8274
# Source 23 → Target 26: 0.7993
# Source 23 → Target 27: 0.7467
# Source 23 → Target 28: 0.7255
# Source 23 → Target 29: 0.7618
# Source 23 → Target 30: 0.8723
# Source 23 → Target 31: 0.7926
# Source 23 → Target 32: 0.7811
# Source 23 → Target 33: 0.7360
# Source 23 → Target 34: 0.8047
# Source 23 → Target 35: 0.9197
# Source 24 → Target  0: 0.9331
# Source 24 → Target  1: 0.8529
# Source 24 → Target  2: 0.7021
# Source 24 → Target  3: 0.8594
# Source 24 → Target  4: 0.8284
# Source 24 → Target  5: 0.8073
# Source 24 → Target  6: 0.8044
# Source 24 → Target  7: 0.7211
# Source 24 → Target  8: 0.8701
# Source 24 → Target  9: 0.6730
# Source 24 → Target 10: 0.9136
# Source 24 → Target 11: 0.8247
# Source 24 → Target 12: 0.8772
# Source 24 → Target 13: 0.5675
# Source 24 → Target 14: 0.8346
# Source 24 → Target 15: 0.6405
# Source 24 → Target 16: 0.6738
# Source 24 → Target 17: 0.7221
# Source 24 → Target 18: 0.7328
# Source 24 → Target 19: 0.7849
# Source 24 → Target 20: 0.6586
# Source 24 → Target 21: 0.8369
# Source 24 → Target 22: 0.8263
# Source 24 → Target 23: 0.8769
# Source 24 → Target 24: 0.7152
# Source 24 → Target 25: 0.7642
# Source 24 → Target 26: 0.7328
# Source 24 → Target 27: 0.6828
# Source 24 → Target 28: 0.6058
# Source 24 → Target 29: 0.6649
# Source 24 → Target 30: 0.8389
# Source 24 → Target 31: 0.7215
# Source 24 → Target 32: 0.6739
# Source 24 → Target 33: 0.6319
# Source 24 → Target 34: 0.7514
# Source 24 → Target 35: 0.9168
# Source 25 → Target  0: 0.9841
# Source 25 → Target  1: 0.9584
# Source 25 → Target  2: 0.9176
# Source 25 → Target  3: 0.9623
# Source 25 → Target  4: 0.9359
# Source 25 → Target  5: 0.9487
# Source 25 → Target  6: 0.9428
# Source 25 → Target  7: 0.9345
# Source 25 → Target  8: 0.9595
# Source 25 → Target  9: 0.8972
# Source 25 → Target 10: 0.9765
# Source 25 → Target 11: 0.9582
# Source 25 → Target 12: 0.9752
# Source 25 → Target 13: 0.8908
# Source 25 → Target 14: 0.9639
# Source 25 → Target 15: 0.9109
# Source 25 → Target 16: 0.9212
# Source 25 → Target 17: 0.9234
# Source 25 → Target 18: 0.9424
# Source 25 → Target 19: 0.9410
# Source 25 → Target 20: 0.9248
# Source 25 → Target 21: 0.9575
# Source 25 → Target 22: 0.9547
# Source 25 → Target 23: 0.9706
# Source 25 → Target 24: 0.9404
# Source 25 → Target 25: 0.9446
# Source 25 → Target 26: 0.9372
# Source 25 → Target 27: 0.9319
# Source 25 → Target 28: 0.9150
# Source 25 → Target 29: 0.9170
# Source 25 → Target 30: 0.9624
# Source 25 → Target 31: 0.9348
# Source 25 → Target 32: 0.9221
# Source 25 → Target 33: 0.9073
# Source 25 → Target 34: 0.9356
# Source 25 → Target 35: 0.9805
# Source 26 → Target  0: 0.9560
# Source 26 → Target  1: 0.8664
# Source 26 → Target  2: 0.6982
# Source 26 → Target  3: 0.8476
# Source 26 → Target  4: 0.7785
# Source 26 → Target  5: 0.8232
# Source 26 → Target  6: 0.8057
# Source 26 → Target  7: 0.7190
# Source 26 → Target  8: 0.8374
# Source 26 → Target  9: 0.6081
# Source 26 → Target 10: 0.9098
# Source 26 → Target 11: 0.8548
# Source 26 → Target 12: 0.8714
# Source 26 → Target 13: 0.6393
# Source 26 → Target 14: 0.8406
# Source 26 → Target 15: 0.6769
# Source 26 → Target 16: 0.6895
# Source 26 → Target 17: 0.7228
# Source 26 → Target 18: 0.7506
# Source 26 → Target 19: 0.7556
# Source 26 → Target 20: 0.6686
# Source 26 → Target 21: 0.8789
# Source 26 → Target 22: 0.8103
# Source 26 → Target 23: 0.8565
# Source 26 → Target 24: 0.7297
# Source 26 → Target 25: 0.7747
# Source 26 → Target 26: 0.7907
# Source 26 → Target 27: 0.7042
# Source 26 → Target 28: 0.6647
# Source 26 → Target 29: 0.7447
# Source 26 → Target 30: 0.8324
# Source 26 → Target 31: 0.7227
# Source 26 → Target 32: 0.7063
# Source 26 → Target 33: 0.6049
# Source 26 → Target 34: 0.7183
# Source 26 → Target 35: 0.9049
# Source 27 → Target  0: 0.9530
# Source 27 → Target  1: 0.8840
# Source 27 → Target  2: 0.7553
# Source 27 → Target  3: 0.8783
# Source 27 → Target  4: 0.8312
# Source 27 → Target  5: 0.8665
# Source 27 → Target  6: 0.8431
# Source 27 → Target  7: 0.8045
# Source 27 → Target  8: 0.8647
# Source 27 → Target  9: 0.6865
# Source 27 → Target 10: 0.9306
# Source 27 → Target 11: 0.8645
# Source 27 → Target 12: 0.9078
# Source 27 → Target 13: 0.6516
# Source 27 → Target 14: 0.8736
# Source 27 → Target 15: 0.7488
# Source 27 → Target 16: 0.7428
# Source 27 → Target 17: 0.7542
# Source 27 → Target 18: 0.7961
# Source 27 → Target 19: 0.8072
# Source 27 → Target 20: 0.7405
# Source 27 → Target 21: 0.8425
# Source 27 → Target 22: 0.8497
# Source 27 → Target 23: 0.9094
# Source 27 → Target 24: 0.7781
# Source 27 → Target 25: 0.8151
# Source 27 → Target 26: 0.7773
# Source 27 → Target 27: 0.7645
# Source 27 → Target 28: 0.7014
# Source 27 → Target 29: 0.7390
# Source 27 → Target 30: 0.8653
# Source 27 → Target 31: 0.7879
# Source 27 → Target 32: 0.7377
# Source 27 → Target 33: 0.6807
# Source 27 → Target 34: 0.7635
# Source 27 → Target 35: 0.9300

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))

plt.imshow(
    r2_matrix.numpy(),
    aspect="auto"
)

plt.colorbar(label="Mean R²")

plt.xlabel("Target Layer")
plt.ylabel("Source Layer")

plt.xticks(range(36))
plt.yticks(range(28))

plt.title("100 Sequence")

plt.show()

# %%
best_matches = {}

for target_layer in range(36):

    scores = r2_matrix[:, target_layer]

    best_source_layer = torch.argmax(scores).item()
    best_r2 = scores[best_source_layer].item()

    best_matches[target_layer] = {
        "source_layer": best_source_layer,
        "r2": best_r2
    }

for target_layer, result in best_matches.items():

    print(
        f"Target layer {target_layer:2d} "
        f"<- Source layer {result['source_layer']:2d} "
        f"R² = {result['r2']:.4f}"
    )
# Out:
# Target layer  0 <- Source layer  0 R² = 0.9944
# Target layer  1 <- Source layer  1 R² = 0.9754
# Target layer  2 <- Source layer  1 R² = 0.9361
# Target layer  3 <- Source layer  1 R² = 0.9674
# Target layer  4 <- Source layer  1 R² = 0.9505
# Target layer  5 <- Source layer  1 R² = 0.9576
# Target layer  6 <- Source layer  1 R² = 0.9579
# Target layer  7 <- Source layer 18 R² = 0.9387
# Target layer  8 <- Source layer 19 R² = 0.9638
# Target layer  9 <- Source layer 19 R² = 0.9034
# Target layer 10 <- Source layer 16 R² = 0.9787
# Target layer 11 <- Source layer 16 R² = 0.9629
# Target layer 12 <- Source layer 16 R² = 0.9789
# Target layer 13 <- Source layer 16 R² = 0.9063
# Target layer 14 <- Source layer 16 R² = 0.9689
# Target layer 15 <- Source layer 16 R² = 0.9274
# Target layer 16 <- Source layer 16 R² = 0.9342
# Target layer 17 <- Source layer 16 R² = 0.9350
# Target layer 18 <- Source layer 16 R² = 0.9539
# Target layer 19 <- Source layer 16 R² = 0.9521
# Target layer 20 <- Source layer 16 R² = 0.9403
# Target layer 21 <- Source layer 16 R² = 0.9642
# Target layer 22 <- Source layer 16 R² = 0.9605
# Target layer 23 <- Source layer 18 R² = 0.9746
# Target layer 24 <- Source layer 16 R² = 0.9471
# Target layer 25 <- Source layer 18 R² = 0.9491
# Target layer 26 <- Source layer 16 R² = 0.9416
# Target layer 27 <- Source layer 19 R² = 0.9364
# Target layer 28 <- Source layer 19 R² = 0.9221
# Target layer 29 <- Source layer 19 R² = 0.9233
# Target layer 30 <- Source layer 25 R² = 0.9624
# Target layer 31 <- Source layer 18 R² = 0.9353
# Target layer 32 <- Source layer 16 R² = 0.9256
# Target layer 33 <- Source layer 19 R² = 0.9100
# Target layer 34 <- Source layer 25 R² = 0.9356
# Target layer 35 <- Source layer 25 R² = 0.9805

# %%
import torch

source_layer = 0
target_layer = 25

head_r2_matrix = torch.zeros(8, 8)

for source_head in range(8):

    for target_head in range(8):

        all_X = []
        all_Y = []

        for i in range(100):

            X = source_kv[i][source_layer][0][source_head]
            Y = target_kv[i][target_layer][0][target_head]

            all_X.append(X)
            all_Y.append(Y)

        X = torch.cat(all_X, dim=0).float()
        Y = torch.cat(all_Y, dim=0).float()

        X_aug = torch.cat(
            [X, torch.ones(X.shape[0], 1)],
            dim=1
        )

        solution = torch.linalg.lstsq(X_aug, Y).solution

        W = solution[:-1]
        b = solution[-1]

        Y_pred = X @ W + b

        ss_res = ((Y - Y_pred) ** 2).sum()
        ss_tot = ((Y - Y.mean(dim=0, keepdim=True)) ** 2).sum()
        r2 = 1 - ss_res / ss_tot

        head_r2_matrix[source_head, target_head] = r2.item()

print(head_r2_matrix)
# Out:
# tensor([[0.9998, 0.9377, 0.9185, 0.9062, 0.8925, 0.8904, 0.8971, 0.8906],
#         [0.9996, 0.9310, 0.9142, 0.8973, 0.8914, 0.8922, 0.8968, 0.8881],
#         [0.9998, 0.9228, 0.9380, 0.9101, 0.9001, 0.8960, 0.8982, 0.8856],
#         [0.9997, 0.9124, 0.9138, 0.9250, 0.9019, 0.9007, 0.9030, 0.8929],
#         [0.9997, 0.9183, 0.9123, 0.9065, 0.9198, 0.9089, 0.9034, 0.8893],
#         [0.9999, 0.9164, 0.9084, 0.9044, 0.9016, 0.9348, 0.9113, 0.8910],
#         [0.9997, 0.9194, 0.9098, 0.8981, 0.8889, 0.9098, 0.9277, 0.9021],
#         [0.9997, 0.9138, 0.9072, 0.9030, 0.8915, 0.8966, 0.9124, 0.9239]])

# %%
for target_head in range(8):

    scores = head_r2_matrix[:, target_head]

    best_source_head = torch.argmax(scores).item()
    best_r2 = scores[best_source_head].item()

    print(
        f"Target head {target_head} "
        f"<- Source head {best_source_head} "
        f"R² = {best_r2:.4f}"
    )
# Out:
# Target head 0 <- Source head 5 R² = 0.9999
# Target head 1 <- Source head 0 R² = 0.9377
# Target head 2 <- Source head 2 R² = 0.9380
# Target head 3 <- Source head 3 R² = 0.9250
# Target head 4 <- Source head 4 R² = 0.9198
# Target head 5 <- Source head 5 R² = 0.9348
# Target head 6 <- Source head 6 R² = 0.9277
# Target head 7 <- Source head 7 R² = 0.9239

# %%
import torch

source_layer = 0
target_layer = 25

source_head = 1
target_head = 3

alpha = 0.1

all_X = []
all_Y = []

for i in range(50):

    X = source_kv[i][source_layer][0][source_head]
    Y = target_kv[i][target_layer][0][target_head]

    all_X.append(X)
    all_Y.append(Y)

X = torch.cat(all_X, dim=0).float()
Y = torch.cat(all_Y, dim=0).float()

X_aug = torch.cat(
    [X, torch.ones(X.shape[0], 1)],
    dim=1
)

n_features = X_aug.shape[1]

I = torch.eye(n_features)

I[-1, -1] = 0

W_full = torch.linalg.solve(
    X_aug.T @ X_aug + alpha * I,
    X_aug.T @ Y
)

W = W_full[:-1]
b = W_full[-1]

Y_pred = X @ W + b

print("W shape:", W.shape)
print("b shape:", b.shape)
# Out:
# W shape: torch.Size([128, 128])
# b shape: torch.Size([128])
